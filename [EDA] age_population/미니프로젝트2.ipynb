# %% [markdown]
# ## 2015.01 - 2018.06

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import koreanize_matplotlib

# %%
from glob import glob
print(glob('data/*.csv'))
# Out:
# ['data/201601_201606_연령별인구현황_월간.csv', 'data/201501_201506_연령별인구현황_월간.csv', 'data/201607_201612_연령별인구현황_월간.csv', 'data/201507_201512_연령별인구현황_월간.csv', 'data/201801_201806_연령별인구현황_월간.csv', 'data/201707_201712_연령별인구현황_월간.csv', 'data/201701_201706_연령별인구현황_월간.csv']

# %%
file_names = sorted(glob('data/*'))
file_names
# Out:
# ['data/201501_201506_연령별인구현황_월간.csv',
#  'data/201507_201512_연령별인구현황_월간.csv',
#  'data/201601_201606_연령별인구현황_월간.csv',
#  'data/201607_201612_연령별인구현황_월간.csv',
#  'data/201701_201706_연령별인구현황_월간.csv',
#  'data/201707_201712_연령별인구현황_월간.csv',
#  'data/201801_201806_연령별인구현황_월간.csv']

# %%
df_1 = pd.read_csv(file_names[0], encoding = "cp949")
df_2 = pd.read_csv(file_names[1], encoding = "cp949")
df_3 = pd.read_csv(file_names[2], encoding = "cp949")
df_4 = pd.read_csv(file_names[3], encoding = "cp949")
df_5 = pd.read_csv(file_names[4], encoding = "cp949")
df_6 = pd.read_csv(file_names[5], encoding = "cp949")
df_7 = pd.read_csv(file_names[6], encoding = "cp949")

# %%
df_1.sample()
# Out:
#                   행정구역 2015년01월_계_총인구수 2015년01월_계_연령구간인구수 2015년01월_계_0~9세  \
# 2  부산광역시  (2600000000)       3,517,898          3,517,898         263,747
#
#   2015년01월_계_10~19세 2015년01월_계_20~29세 2015년01월_계_30~39세 2015년01월_계_40~49세  \
# 2           365,123           455,687           503,003           576,949
#
#   2015년01월_계_50~59세 2015년01월_계_60~69세  ... 2015년06월_계_10~19세  \
# 2           628,752           404,630  ...           356,680
#
#   2015년06월_계_20~29세 2015년06월_계_30~39세 2015년06월_계_40~49세 2015년06월_계_50~59세  \
# 2           456,347           498,604           573,651           623,045
#
#   2015년06월_계_60~69세 2015년06월_계_70~79세 2015년06월_계_80~89세 2015년06월_계_90~99세  \
# 2           417,140           239,962            75,987             9,125
#
#   2015년06월_계_100세 이상
# 2              1,446
#
# [1 rows x 79 columns]

# %%
df_1 = df_1.melt(id_vars = '행정구역', var_name = '기간', value_name = '인구수')
df_2 = df_2.melt(id_vars = '행정구역', var_name = '기간', value_name = '인구수')
df_3 = df_3.melt(id_vars = '행정구역', var_name = '기간', value_name = '인구수')
df_4 = df_4.melt(id_vars = '행정구역', var_name = '기간', value_name = '인구수')
df_5 = df_5.melt(id_vars = '행정구역', var_name = '기간', value_name = '인구수')
df_6 = df_6.melt(id_vars = '행정구역', var_name = '기간', value_name = '인구수')
df_7 = df_7.melt(id_vars = '행정구역', var_name = '기간', value_name = '인구수')

# %%
df_1.sample()
# Out:
#                      행정구역                 기간      인구수
# 1246  인천광역시  (2800000000)  2015년06월_계_20~29세  400,379

# %%
df_2.sample()
# Out:
#                    행정구역                 기간      인구수
# 591  경상북도  (4700000000)  2015년09월_계_40~49세  430,724

# %%
df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7])
df.to_csv('201501_201806_전처리전.csv', index = False)

# %%
df['지역코드'] = df['행정구역'].str[-11:-1]
df.head()
# Out:
#                   행정구역               기간         인구수        지역코드
# 0     전국  (0000000000)  2015년01월_계_총인구수  51,342,881  0000000000
# 1  서울특별시  (1100000000)  2015년01월_계_총인구수  10,104,515  1100000000
# 2  부산광역시  (2600000000)  2015년01월_계_총인구수   3,517,898  2600000000
# 3  대구광역시  (2700000000)  2015년01월_계_총인구수   2,492,658  2700000000
# 4  인천광역시  (2800000000)  2015년01월_계_총인구수   2,904,876  2800000000

# %%
df['연도'] = df['기간'].map(lambda x : int(x.split('_')[0][:4]))
df['월'] = df['기간'].map(lambda x : int(x.split('_')[0][-3:-1]))
df.sample(3)
# Out:
#                        행정구역                 기간        인구수        지역코드    연도  월
# 355      전라북도  (4500000000)  2015년08월_계_40~49세    301,827  4500000000  2015  8
# 1358  세종특별자치시  (3600000000)  2017년06월_계_80~89세      5,521  3600000000  2017  6
# 1297    서울특별시  (1100000000)  2015년06월_계_50~59세  1,592,373  1100000000  2015  6

# %%
df['연령대'] = df['기간'].map(lambda x : x.split('_')[-1])
df.sample(4)
# Out:
#                       행정구역                  기간      인구수        지역코드    연도  월  \
# 676      강원도  (4200000000)   2017년03월_계_90~99세    8,277  4200000000  2017  3
# 60     대전광역시  (3000000000)   2018년01월_계_10~19세  167,350  3000000000  2018  1
# 269  제주특별자치도  (5000000000)  2015년08월_계_연령구간인구수  618,447  5000000000  2015  8
# 301     전라북도  (4500000000)   2017년08월_계_10~19세  201,911  4500000000  2017  8
#
#          연령대
# 676   90~99세
# 60    10~19세
# 269  연령구간인구수
# 301   10~19세

# %%
df['행정구역'] = df['행정구역'].str.replace('[^가-힣]', '', regex = True).str.strip()
df.sample(3)
# Out:
#       행정구역                 기간        인구수        지역코드    연도  월     연령대
# 600  대전광역시  2017년03월_계_50~59세    240,057  3000000000  2017  3  50~59세
# 516   충청남도    2016년03월_계_0~9세    197,300  4400000000  2016  3    0~9세
# 238  인천광역시    2015년02월_계_총인구수  2,906,603  2800000000  2015  2    총인구수

# %%
columns = ['행정구역', '지역코드', '연도', '월', '연령대', '인구수']
df = df[columns]
df.sample(10)
# Out:
#          행정구역        지역코드    연도   월      연령대        인구수
# 1002     충청남도  4400000000  2015   5   10~19세    233,557
# 901     서울특별시  1100000000  2016   4   90~99세     30,374
# 733      전라북도  4500000000  2015  10  연령구간인구수  1,869,297
# 748       강원도  4200000000  2017  10     0~9세    117,382
# 1358  세종특별자치시  3600000000  2016  12   80~89세      5,219
# 973     서울특별시  1100000000  2017   5     0~9세    750,415
# 699      경상북도  4700000000  2017   3  100세 이상        805
# 1316    부산광역시  2600000000  2015  12   60~69세    432,899
# 484      경상남도  4800000000  2016   3     총인구수  3,365,021
# 770      전라남도  4600000000  2017  10   10~19세    192,542

# %%
df = df.loc[(df['행정구역'] != '전국') & (df['연령대'] != '연령구간인구수') & (df['연령대'] != '총인구수')]
df['연령대'].value_counts()
# Out:
# 0~9세       714
# 10~19세     714
# 20~29세     714
# 30~39세     714
# 40~49세     714
# 50~59세     714
# 60~69세     714
# 70~79세     714
# 80~89세     714
# 90~99세     714
# 100세 이상    714
# Name: 연령대, dtype: int64

# %%
df = df.drop('지역코드', axis = 1).reset_index(drop = True)

# %%
df['인구수'] = df['인구수'].str.replace('[^0-9]', '', regex = True).astype(int)
df.head(2)
# Out:
#     행정구역    연도  월   연령대     인구수
# 0  서울특별시  2015  1  0~9세  792353
# 1  부산광역시  2015  1  0~9세  263747

# %%
df.head()
# Out:
#     행정구역    연도  월   연령대     인구수
# 0  서울특별시  2015  1  0~9세  792353
# 1  부산광역시  2015  1  0~9세  263747
# 2  대구광역시  2015  1  0~9세  208324
# 3  인천광역시  2015  1  0~9세  269998
# 4  광주광역시  2015  1  0~9세  144939

# %%
df['연도'].unique()
# Out:
# array([2015, 2016, 2017, 2018])

# %%
df['행정구역'].value_counts()
# Out:
# 서울특별시      462
# 강원도        462
# 경상남도       462
# 경상북도       462
# 전라남도       462
# 전라북도       462
# 충청남도       462
# 충청북도       462
# 경기도        462
# 부산광역시      462
# 세종특별자치시    462
# 울산광역시      462
# 대전광역시      462
# 광주광역시      462
# 인천광역시      462
# 대구광역시      462
# 제주특별자치도    462
# Name: 행정구역, dtype: int64

# %%
df.to_csv('data/201501_201806.csv', index = False)

# %%
pd.read_csv('data/201501_201806.csv')
# Out:
#          행정구역    연도  월      연령대     인구수
# 0       서울특별시  2015  1     0~9세  792353
# 1       부산광역시  2015  1     0~9세  263747
# 2       대구광역시  2015  1     0~9세  208324
# 3       인천광역시  2015  1     0~9세  269998
# 4       광주광역시  2015  1     0~9세  144939
# ...       ...   ... ..      ...     ...
# 7849     전라북도  2018  6  100세 이상     721
# 7850     전라남도  2018  6  100세 이상     773
# 7851     경상북도  2018  6  100세 이상     828
# 7852     경상남도  2018  6  100세 이상     675
# 7853  제주특별자치도  2018  6  100세 이상     251
#
# [7854 rows x 5 columns]

# %%
df.hist(figsize = (20, 7))
# Out:
# array([[<AxesSubplot:title={'center':'연도'}>,
#         <AxesSubplot:title={'center':'월'}>],
#        [<AxesSubplot:title={'center':'인구수'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
pd.crosstab(df['연령대'], df['행정구역'], aggfunc = "sum", values = df['인구수']).T.style.background_gradient(cmap = "summer_r")
# Out:
# <style type="text/css">
# #T_4a827_row0_col0, #T_4a827_row0_col4, #T_4a827_row10_col5, #T_4a827_row14_col10 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_4a827_row0_col1, #T_4a827_row4_col2, #T_4a827_row6_col3, #T_4a827_row6_col7, #T_4a827_row13_col3 {
#   background-color: #e2f066;
#   color: #000000;
# }
# #T_4a827_row0_col2, #T_4a827_row0_col3, #T_4a827_row4_col5, #T_4a827_row4_col6, #T_4a827_row6_col4, #T_4a827_row6_col5, #T_4a827_row13_col4, #T_4a827_row16_col5 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_4a827_row0_col5, #T_4a827_row12_col4 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_4a827_row0_col6, #T_4a827_row12_col2 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_4a827_row0_col7, #T_4a827_row15_col6 {
#   background-color: #d9ec66;
#   color: #000000;
# }
# #T_4a827_row0_col8, #T_4a827_row0_col9, #T_4a827_row11_col0 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_4a827_row0_col10, #T_4a827_row5_col9, #T_4a827_row7_col2, #T_4a827_row11_col4 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_4a827_row1_col0, #T_4a827_row1_col2, #T_4a827_row1_col3, #T_4a827_row1_col4, #T_4a827_row1_col5, #T_4a827_row1_col6, #T_4a827_row1_col7, #T_4a827_row1_col8, #T_4a827_row1_col9, #T_4a827_row1_col10, #T_4a827_row8_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_4a827_row1_col1 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_4a827_row2_col0, #T_4a827_row13_col8 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_4a827_row2_col1, #T_4a827_row13_col5 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_4a827_row2_col2 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_4a827_row2_col3, #T_4a827_row5_col8 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_4a827_row2_col4 {
#   background-color: #c7e366;
#   color: #000000;
# }
# #T_4a827_row2_col5, #T_4a827_row11_col6, #T_4a827_row11_col7, #T_4a827_row15_col8 {
#   background-color: #c3e166;
#   color: #000000;
# }
# #T_4a827_row2_col6 {
#   background-color: #bbdd66;
#   color: #000000;
# }
# #T_4a827_row2_col7 {
#   background-color: #afd766;
#   color: #000000;
# }
# #T_4a827_row2_col8, #T_4a827_row12_col9 {
#   background-color: #aad466;
#   color: #000000;
# }
# #T_4a827_row2_col9, #T_4a827_row7_col8 {
#   background-color: #9fcf66;
#   color: #000000;
# }
# #T_4a827_row2_col10 {
#   background-color: #aed666;
#   color: #000000;
# }
# #T_4a827_row3_col0, #T_4a827_row3_col4, #T_4a827_row5_col4 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_4a827_row3_col1, #T_4a827_row15_col2, #T_4a827_row16_col7 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_4a827_row3_col2, #T_4a827_row3_col3, #T_4a827_row5_col5 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_4a827_row3_col5, #T_4a827_row5_col10, #T_4a827_row16_col8, #T_4a827_row16_col10 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_4a827_row3_col6, #T_4a827_row11_col8, #T_4a827_row11_col9 {
#   background-color: #c8e366;
#   color: #000000;
# }
# #T_4a827_row3_col7 {
#   background-color: #b5da66;
#   color: #000000;
# }
# #T_4a827_row3_col8 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_4a827_row3_col9 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_4a827_row3_col10 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_4a827_row4_col0, #T_4a827_row4_col4, #T_4a827_row6_col0, #T_4a827_row10_col6, #T_4a827_row16_col0, #T_4a827_row16_col4 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_4a827_row4_col1, #T_4a827_row10_col8 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_4a827_row4_col3, #T_4a827_row4_col7, #T_4a827_row4_col8, #T_4a827_row6_col2, #T_4a827_row6_col6, #T_4a827_row6_col8, #T_4a827_row12_col3, #T_4a827_row12_col5 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_4a827_row4_col9, #T_4a827_row6_col9, #T_4a827_row16_col2, #T_4a827_row16_col3 {
#   background-color: #e5f266;
#   color: #000000;
# }
# #T_4a827_row4_col10, #T_4a827_row5_col1, #T_4a827_row6_col10, #T_4a827_row12_col0, #T_4a827_row13_col0 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_4a827_row5_col0, #T_4a827_row12_col6 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_4a827_row5_col2 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_4a827_row5_col3, #T_4a827_row13_col7, #T_4a827_row16_col9 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_4a827_row5_col6, #T_4a827_row12_col7 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_4a827_row5_col7, #T_4a827_row7_col4, #T_4a827_row7_col5, #T_4a827_row11_col3, #T_4a827_row11_col10 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_4a827_row6_col1, #T_4a827_row10_col9, #T_4a827_row14_col8 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_4a827_row7_col0, #T_4a827_row15_col7 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_4a827_row7_col1, #T_4a827_row12_col8 {
#   background-color: #b6db66;
#   color: #000000;
# }
# #T_4a827_row7_col3 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_4a827_row7_col6 {
#   background-color: #b4da66;
#   color: #000000;
# }
# #T_4a827_row7_col7 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_4a827_row7_col9 {
#   background-color: #add666;
#   color: #000000;
# }
# #T_4a827_row7_col10, #T_4a827_row13_col9 {
#   background-color: #b8dc66;
#   color: #000000;
# }
# #T_4a827_row8_col0 {
#   background-color: #65b266;
#   color: #f1f1f1;
# }
# #T_4a827_row8_col2 {
#   background-color: #5aac66;
#   color: #f1f1f1;
# }
# #T_4a827_row8_col3 {
#   background-color: #229066;
#   color: #f1f1f1;
# }
# #T_4a827_row8_col4 {
#   background-color: #2b9566;
#   color: #f1f1f1;
# }
# #T_4a827_row8_col5 {
#   background-color: #46a266;
#   color: #f1f1f1;
# }
# #T_4a827_row8_col6 {
#   background-color: #389c66;
#   color: #f1f1f1;
# }
# #T_4a827_row8_col7 {
#   background-color: #068266;
#   color: #f1f1f1;
# }
# #T_4a827_row8_col8 {
#   background-color: #0e8666;
#   color: #f1f1f1;
# }
# #T_4a827_row8_col9 {
#   background-color: #2f9766;
#   color: #f1f1f1;
# }
# #T_4a827_row8_col10 {
#   background-color: #1d8e66;
#   color: #f1f1f1;
# }
# #T_4a827_row9_col0, #T_4a827_row9_col1, #T_4a827_row9_col2, #T_4a827_row9_col3, #T_4a827_row9_col4, #T_4a827_row9_col5, #T_4a827_row9_col6, #T_4a827_row9_col7, #T_4a827_row9_col8, #T_4a827_row9_col9, #T_4a827_row9_col10 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_4a827_row10_col0, #T_4a827_row10_col4 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_4a827_row10_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_4a827_row10_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_4a827_row10_col3, #T_4a827_row16_col1 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_4a827_row10_col7 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_4a827_row10_col10 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_4a827_row11_col1, #T_4a827_row12_col1, #T_4a827_row13_col6, #T_4a827_row15_col0, #T_4a827_row15_col3 {
#   background-color: #ddee66;
#   color: #000000;
# }
# #T_4a827_row11_col2 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_4a827_row11_col5 {
#   background-color: #cae466;
#   color: #000000;
# }
# #T_4a827_row12_col10 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_4a827_row13_col1, #T_4a827_row16_col6 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_4a827_row13_col2, #T_4a827_row15_col1, #T_4a827_row15_col5 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_4a827_row13_col10 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_4a827_row14_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_4a827_row14_col1, #T_4a827_row14_col6 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_4a827_row14_col2 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_4a827_row14_col3, #T_4a827_row14_col5 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_4a827_row14_col4 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_4a827_row14_col7 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_4a827_row14_col9 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_4a827_row15_col4 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_4a827_row15_col9 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_4a827_row15_col10 {
#   background-color: #badc66;
#   color: #000000;
# }
# </style>
# <table id="T_4a827">
#   <thead>

# %%
pd.crosstab(df['연도'], df['행정구역'], aggfunc = "sum", values = df['인구수']).T.plot(kind = 'bar', rot = 0, stacked = True, figsize = (15, 10), legend = 'reverse')
# Out:
# <AxesSubplot:xlabel='행정구역'>

# %%
pd.crosstab(df['연령대'], df['행정구역'], aggfunc = "sum", values = df['인구수']).T.plot(kind = 'bar', rot = 0, stacked = True, figsize = (15, 10), legend = 'reverse')
# Out:
# <AxesSubplot:xlabel='행정구역'>

# %%
# plt.figure(figsize = (10,5))
sns.catplot(data = df, x = '연령대', y = '인구수', hue = '행정구역', col = '연도', col_wrap = 3, ci = None)

# %%
plt.figure(figsize = (16,8))
sns.catplot(data = df.sort_values('인구수', ascending = False), x = '연령대', y = '인구수', col = '행정구역', kind = 'bar', estimator = np.sum, height = 3, col_wrap = 4, ci = None)
plt.show()

# %%
pd.pivot_table(data = df, index = '행정구역', columns = '연령대', values = '인구수', aggfunc = 'sum').style.bar()
# Out:
# <style type="text/css">
# #T_fe44a_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.7%, transparent 9.7%);
# }
# #T_fe44a_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.1%, transparent 12.1%);
# }
# #T_fe44a_row0_col2, #T_fe44a_row6_col0, #T_fe44a_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.4%, transparent 11.4%);
# }
# #T_fe44a_row0_col3, #T_fe44a_row4_col4, #T_fe44a_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.0%, transparent 11.0%);
# }
# #T_fe44a_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.5%, transparent 9.5%);
# }
# #T_fe44a_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.7%, transparent 10.7%);
# }
# #T_fe44a_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.4%, transparent 13.4%);
# }
# #T_fe44a_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.5%, transparent 16.5%);
# }
# #T_fe44a_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.8%, transparent 20.8%);
# }
# #T_fe44a_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.1%, transparent 21.1%);
# }
# #T_fe44a_row0_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.9%, transparent 22.9%);
# }
# #T_fe44a_row1_col0, #T_fe44a_row1_col2, #T_fe44a_row1_col3, #T_fe44a_row1_col4, #T_fe44a_row1_col5, #T_fe44a_row1_col6, #T_fe44a_row1_col7, #T_fe44a_row1_col8, #T_fe44a_row1_col9, #T_fe44a_row1_col10, #T_fe44a_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_fe44a_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 60.3%, transparent 60.3%);
# }
# #T_fe44a_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.3%, transparent 25.3%);
# }
# #T_fe44a_row2_col1, #T_fe44a_row4_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.7%, transparent 11.7%);
# }
# #T_fe44a_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.6%, transparent 25.6%);
# }
# #T_fe44a_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 23.6%, transparent 23.6%);
# }
# #T_fe44a_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 23.9%, transparent 23.9%);
# }
# #T_fe44a_row2_col5, #T_fe44a_row11_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.9%, transparent 24.9%);
# }
# #T_fe44a_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.8%, transparent 27.8%);
# }
# #T_fe44a_row2_col7, #T_fe44a_row12_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.5%, transparent 32.5%);
# }
# #T_fe44a_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.4%, transparent 34.4%);
# }
# #T_fe44a_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.1%, transparent 39.1%);
# }
# #T_fe44a_row2_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.0%, transparent 33.0%);
# }
# #T_fe44a_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.7%, transparent 17.7%);
# }
# #T_fe44a_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.7%, transparent 14.7%);
# }
# #T_fe44a_row3_col2, #T_fe44a_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.4%, transparent 18.4%);
# }
# #T_fe44a_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.4%, transparent 17.4%);
# }
# #T_fe44a_row3_col5, #T_fe44a_row5_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.3%, transparent 18.3%);
# }
# #T_fe44a_row3_col6, #T_fe44a_row5_col9, #T_fe44a_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.8%, transparent 22.8%);
# }
# #T_fe44a_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 30.2%, transparent 30.2%);
# }
# #T_fe44a_row3_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.8%, transparent 35.8%);
# }
# #T_fe44a_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 42.3%, transparent 42.3%);
# }
# #T_fe44a_row3_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 38.3%, transparent 38.3%);
# }
# #T_fe44a_row4_col0, #T_fe44a_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.3%, transparent 11.3%);
# }
# #T_fe44a_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.4%, transparent 6.4%);
# }
# #T_fe44a_row4_col2, #T_fe44a_row16_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.1%, transparent 13.1%);
# }
# #T_fe44a_row4_col3, #T_fe44a_row4_col7, #T_fe44a_row4_col9, #T_fe44a_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.0%, transparent 12.0%);
# }
# #T_fe44a_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.1%, transparent 11.1%);
# }
# #T_fe44a_row4_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.4%, transparent 12.4%);
# }
# #T_fe44a_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.6%, transparent 16.6%);
# }
# #T_fe44a_row5_col1, #T_fe44a_row16_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.9%, transparent 10.9%);
# }
# #T_fe44a_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.1%, transparent 19.1%);
# }
# #T_fe44a_row5_col3, #T_fe44a_row13_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.7%, transparent 19.7%);
# }
# #T_fe44a_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.2%, transparent 17.2%);
# }
# #T_fe44a_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.7%, transparent 18.7%);
# }
# #T_fe44a_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.0%, transparent 21.0%);
# }
# #T_fe44a_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.3%, transparent 24.3%);
# }
# #T_fe44a_row5_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 23.8%, transparent 23.8%);
# }
# #T_fe44a_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.7%, transparent 5.7%);
# }
# #T_fe44a_row6_col2, #T_fe44a_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.3%, transparent 12.3%);
# }
# #T_fe44a_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.7%, transparent 12.7%);
# }
# #T_fe44a_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.5%, transparent 11.5%);
# }
# #T_fe44a_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.9%, transparent 11.9%);
# }
# #T_fe44a_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.9%, transparent 12.9%);
# }
# #T_fe44a_row6_col8, #T_fe44a_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.2%, transparent 12.2%);
# }
# #T_fe44a_row6_col10, #T_fe44a_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.8%, transparent 11.8%);
# }
# #T_fe44a_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.3%, transparent 21.3%);
# }
# #T_fe44a_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.2%, transparent 29.2%);
# }
# #T_fe44a_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.1%, transparent 27.1%);
# }
# #T_fe44a_row7_col4, #T_fe44a_row11_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.8%, transparent 24.8%);
# }
# #T_fe44a_row7_col5, #T_fe44a_row11_col3, #T_fe44a_row11_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.2%, transparent 24.2%);
# }
# #T_fe44a_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 30.5%, transparent 30.5%);
# }
# #T_fe44a_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 41.0%, transparent 41.0%);
# }
# #T_fe44a_row7_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 38.7%, transparent 38.7%);
# }
# #T_fe44a_row7_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.7%, transparent 33.7%);
# }
# #T_fe44a_row7_col10 {

# %%
df.groupby(by = ['행정구역', '연령대'])[['인구수']].sum()
# Out:
#                    인구수
# 행정구역 연령대
# 강원도  0~9세      5069813
#      100세 이상     26898
#      10~19세    6940353
#      20~29세    7715958
#      30~39세    7804319
# ...                ...
# 충청북도 50~59세   11050967
#      60~69세    7049946
#      70~79세    4838492
#      80~89세    2138981
#      90~99세     268673
#
# [187 rows x 1 columns]

# %%
df.groupby(by = ['행정구역', '연령대'])['인구수'].sum().unstack()
# Out:
# 연령대          0~9세  100세 이상    10~19세    20~29세    30~39세    40~49세    50~59세  \
# 행정구역
# 강원도       5069813    26898   6940353   7715958   7804319  10357802  11345040
# 경기도      52147545   133563  61046802  70285951  82167943  96927523  84387559
# 경상남도     13168913    25995  15654354  16589402  19645664  24123165  23488538
# 경상북도      9251459    32598  11245813  12912704  14284955  17735079  19260119
# 광주광역시     5902321    14097   7984674   8447183   9038863  10776326   9290900
# 대구광역시     8635282    24092  11689810  13818894  14101332  18119369  17718055
# 대전광역시     5937218    12588   7487617   8920397   9408894  11084643  10038144
# 부산광역시    11095988    64657  13914350  19081111  20343797  23471974  25713308
# 서울특별시    31956714   221529  39894380  60901097  68665953  70627307  66156531
# 세종특별자치시   1411299     1792   1123590   1074680   1863672   1806022   1209222
# 울산광역시     4819502     5946   5645550   6617491   7430542   8719465   8562151
# 인천광역시    11223108    30980  13236745  17010844  18900106  21519422  20977363
# 전라남도      6520693    31455   8494266   8607439   9213839  12072017  13105503
# 전라북도      6561338    28286   8830611   9167854   9495730  12440697  12507309
# 제주특별자치도   2673361     9589   3204620   3187629   3631995   4710710   4185338
# 충청남도      8233325    29801   9436919  10279603  12403733  14057110  13586899
# 충청북도      5897360    19284   7306327   8279021   8952925  10900414  11050967
#
# 연령대        60~69세    70~79세    80~89세   90~99세
# 행정구역
# 강원도       7583663   5593034   2224087   338197
# 경기도      45901069  26921818  10528711  1480063
# 경상남도     14922170   9249409   4115790   488326
# 경상북도     13846323   9642435   4449702   567351
# 광주광역시     5523414   3334152   1265470   173126
# 대구광역시    11145220   6394020   2400949   271021
# 대전광역시     5937760   3286203   1299651   174435
# 부산광역시    18807406  10413865   3551398   434306
# 서울특별시    44760140  25388577   8614591  1314465
# 세종특별자치시    743620    455750    215338    28878
# 울산광역시     4490766   2001602    715499    92358
# 인천광역시    11367824   6221238   2445184   357736
# 전라남도      9609306   8025293   3652733   480909
# 전라북도      9059681   6610964   3109887   395258
# 제주특별자치도   2559554   1703461    771999   131545
# 충청남도      9333257   6758594   3346078   421371
# 충청북도      7049946   4838492   2138981   268673

# %%
df.groupby(by = ['행정구역', '연령대'])['인구수'].describe()
# Out:
#               count           mean           std       min        25%  \
# 행정구역 연령대
# 강원도  0~9세      42.0  120709.833333   3047.726725  114581.0  118509.50
#      100세 이상   42.0     640.428571     43.856831     560.0     606.50
#      10~19세    42.0  165246.500000   7462.561354  153344.0  158842.50
#      20~29세    42.0  183713.285714    950.283893  181364.0  183377.75
#      30~39세    42.0  185817.119048   4700.163107  177312.0  182091.00
# ...             ...            ...           ...       ...        ...
# 충청북도 50~59세    42.0  263118.261905   4153.329115  255394.0  259466.00
#      60~69세    42.0  167855.857143  12055.112092  147690.0  157211.50
#      70~79세    42.0  115202.190476   1077.342264  113349.0  114279.50
#      80~89세    42.0   50928.119048   3942.721297   44101.0   47308.50
#      90~99세    42.0    6396.976190    509.814050    5591.0    6009.00
#
#                    50%       75%       max
# 행정구역 연령대
# 강원도  0~9세     121821.0  123257.0  124196.0
#      100세 이상     644.0     673.5     705.0
#      10~19세   164904.5  171790.0  177970.0
#      20~29세   183693.5  184369.0  185914.0
#      30~39세   186463.0  189968.5  193755.0
# ...                ...       ...       ...
# 충청북도 50~59세   263569.5  266563.5  269092.0
#      60~69세   167584.5  177546.5  187709.0
#      70~79세   115243.5  115935.5  117320.0
#      80~89세    50888.0   54140.0   57179.0
#      90~99세     6278.5    6830.5    7308.0
#
# [187 rows x 8 columns]

# %%
from glob import glob
file_names = glob('*.csv')
file_names
# Out:
# ['200801_201106.csv', '201501_201806.csv', '201807_202112.csv']
